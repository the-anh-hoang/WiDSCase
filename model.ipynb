# %%
import pandas as pd

# %%
training = pd.read_csv('data/train.csv')
testing = pd.read_csv('data/test.csv')

training.head()
# Out:
#    Unnamed: 0                   id  \
# 0         879             19792418
# 1        6416  1015650685503221866
# 2        1820             35265562
# 3        5346   911948980885194155
# 4        2484             46069251
#
#                                                 name  \
# 0  Home in Vancouver · ★4.75 · 1 bedroom · 1 bed ...
# 1  Guest suite in Vancouver · ★New · 2 bedrooms ·...
# 2  Guest suite in Vancouver · ★4.85 · 2 bedrooms ...
# 3  Home in Vancouver · ★5.0 · 1 bedroom · 1 bed ·...
# 4  Guest suite in Vancouver · ★4.93 · 1 bedroom ·...
#
#                                neighborhood_overview    host_id host_name  \
# 0  Everything you need is nearby. <br /><br />Hig...   57488206     Jessi
# 1                                                NaN  139792573    Daniel
# 2  Beautiful neighbourhood close to prosperous Ma...  265504225      Alex
# 3  We are located in a quiet residential neighbor...   22595056   Raymond
# ...

# %%
testing.head()
# Out:
#                    id                                               name  \
# 0             4465400  Home in Vancouver · ★4.98 · 4 bedrooms · 4 bed...
# 1  608629349064811166  Rental unit in Vancouver · 1 bedroom · 1 bed ·...
# 2  981894508939312892  Rental unit in Vancouver · ★5.0 · 1 bedroom · ...
# 3            52014961  Guest suite in Vancouver · ★4.79 · 2 bedrooms ...
# 4  836285112356489303  Rental unit in Vancouver · ★5.0 · 1 bedroom · ...
#
#                                neighborhood_overview    host_id  \
# 0  We are less than a block to Kits pool - the la...   23168796
# 1  One of the most eclectic areas in the Lower Ma...   16926150
# 2  Le Soleil Hotel and Suites is situated in the ...  536871978
# 3  Very safe and quite area,also very convenient ...  421206568
# 4  Mount Pleasant is a largely residential area w...  227662329
#
#            host_name  host_response_time host_response_rate  \
# 0  Oliver & Ashleigh  within a few hours               100%
# ...
